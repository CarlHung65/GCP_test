# %%
import googlemaps
import pandas as pd

# %%
gmaps = googlemaps.Client(key="AIzaSyD3_9x9JK7SZWIgNYP0izWScv6JT3otE2I")

# %%
nightmarkets = ["基隆市基隆廟口夜市","基隆市八斗子夜市",
               "臺北市公館夜市","新北市長興街福德祠夜市",
               "新竹市中正台夜市","新竹縣關西夜市",]

NMs = []
for nightmarket in nightmarkets:
    gm = gmaps.geocode(nightmarket)
    lat = gm[0]['geometry']['location']['lat']
    lng = gm[0]['geometry']['location']['lng']
    print(f"{nightmarket}\n{lat}\n{lng}")
# Out:
# 基隆市基隆廟口夜市
# 25.128445
# 121.7431519
# 基隆市八斗子夜市
# 25.1426177
# 121.7899976
# 臺北市公館夜市
# 25.0137201
# 121.5347221
# 新北市長興街福德祠夜市
# 25.0796737
# 121.6709747
# 新竹市中正台夜市
# 24.8032411
# 120.9685613
# 新竹縣關西夜市
# 24.7829333
# 121.1784034

# %%
nightmarkets = ["基隆廟口夜市","八斗子夜市",
               "公館夜市","長興街福德祠夜市",
               "葫蘆墩觀光夜市","SOGO停車場夜市",]
NMs = []
for nightmarket in nightmarkets:
    gm = gmaps.geocode(nightmarket)
    lat = gm[0]['geometry']['location']['lat']
    lng = gm[0]['geometry']['location']['lng']
    print(f"{nightmarket}\n{lat}\n{lng}")
# Out:
# 基隆廟口夜市
# 25.128445
# 121.7431519
# 八斗子夜市
# 25.1426177
# 121.7899976
# 公館夜市
# 25.0137201
# 121.5347221
# 長興街福德祠夜市
# 25.0796737
# 121.6709747
# 葫蘆墩觀光夜市
# 24.249009
# 120.730445
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 7
#       5 for nightmarket in nightmarkets:
#       6     gm = gmaps.geocode(nightmarket)
# ----> 7     lat = gm[0]['geometry']['location']['lat']
#       8     lng = gm[0]['geometry']['location']['lng']
#       9     print(f"{nightmarket}\n{lat}\n{lng}")
#
# IndexError: list index out of range
